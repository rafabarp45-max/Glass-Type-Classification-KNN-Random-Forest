# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('glass_data.csv')
df
# Out:
#       id       ri     na    mg    al     si     k    ca    ba   fe  type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
df.drop(columns=['id'], inplace=True)

# %%
df.head()
# Out:
#         ri     na    mg    al     si     k    ca   ba   fe  type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.isnull().sum()
# Out:
# ri      0
# na      0
# mg      0
# al      0
# si      0
# k       0
# ca      0
# ba      0
# fe      0
# type    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                ri          na          mg          al          si           k  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518348   13.404085    2.679202    1.449484   72.655070    0.498873
# std      0.003033    0.816662    1.443691    0.495925    0.773998    0.653185
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.810000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                ca          ba          fe        type
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.954085    0.175869    0.057277    2.788732
# std      1.425882    0.498245    0.097589    2.105130
# ...

# %%
df.dtypes
# Out:
# ri      float64
# na      float64
# mg      float64
# al      float64
# si      float64
# k       float64
# ca      float64
# ba      float64
# fe      float64
# type      int64
# dtype: object

# %%
sns.boxplot(x='type', y='ri', data=df)
plt.title('Boxplot of RI by Type')
plt.show()

# %%
sns.boxplot(x='type', y='na', data=df)
plt.title('Boxplot of Na by Type')
plt.show()

# %%
sns.boxplot(x='type', y='mg', data=df)
plt.title('Boxplot of Mg by Type')
plt.show()

# %%
sns.boxplot(x='type', y='al', data=df)
plt.title('Boxplot of Al by Type')
plt.show()

# %%
sns.boxplot(x='type', y='si', data=df)
plt.title('Boxplot of Si by Type')
plt.show()

# %%
sns.boxplot(x='type', y='k', data=df)
plt.title('Boxplot of K by Type')
plt.show()

# %%
sns.boxplot(x='type', y='ca', data=df)
plt.title('Boxplot of Ca by Type')
plt.show()

# %%
sns.boxplot(x='type', y='ba', data=df)
plt.title('Boxplot of Ba by Type')
plt.show()

# %%
sns.boxplot(x='type', y='fe', data=df)
plt.title('Boxplot of Fe by Type')
plt.show()

# %%
df.head()
# Out:
#         ri     na    mg    al     si     k    ca   ba   fe  type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
sns.histplot(df['ri'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of RI')
plt.xlabel('RI')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['na'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Na')
plt.xlabel('Na')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['mg'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Mg')
plt.xlabel('Mg')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['al'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Al')
plt.xlabel('Al')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['si'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Si')
plt.xlabel('Si')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['k'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of K')
plt.xlabel('K')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['ca'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Ca')
plt.xlabel('Ca')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['ba'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Ba')
plt.xlabel('Ba')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['fe'], kde=True, bins=20, edgecolor='black')
plt.title('Histogram of Fe')
plt.xlabel('Fe')
plt.ylabel('Frequency')
plt.show()

# %%
from scipy import stats

for col in df.select_dtypes(include='number').columns:
    stat, p = stats.shapiro(df[col])
    resultado = "Normal ✅" if p > 0.05 else "Non Normal ❌"
    print(f"{col}: p={p:.4f} → {resultado}")
# Out:
# ri: p=0.0000 → Non Normal ❌
# na: p=0.0000 → Non Normal ❌
# mg: p=0.0000 → Non Normal ❌
# al: p=0.0000 → Non Normal ❌
# si: p=0.0000 → Non Normal ❌
# k: p=0.0000 → Non Normal ❌
# ca: p=0.0000 → Non Normal ❌
# ba: p=0.0000 → Non Normal ❌
# fe: p=0.0000 → Non Normal ❌
# type: p=0.0000 → Non Normal ❌

# %%
from scipy.stats import levene

for col in df.select_dtypes(include='number').columns:
    grupos = [df[df['type'] == t][col] for t in df['type'].unique()]
    stat, p = levene(*grupos)
    resultado = "Homogeneous ✅" if p > 0.05 else "Non Homogeneous ❌"
    print(f"{col}: p={p:.4f} → {resultado}")
# Out:
# ri: p=0.3861 → Homogeneous ✅
# na: p=0.7126 → Homogeneous ✅
# mg: p=0.0009 → Non Homogeneous ❌
# al: p=0.0018 → Non Homogeneous ❌
# si: p=0.0558 → Homogeneous ✅
# k: p=0.0000 → Non Homogeneous ❌
# ca: p=0.0024 → Non Homogeneous ❌
# ba: p=0.0000 → Non Homogeneous ❌
# fe: p=0.0217 → Non Homogeneous ❌
# type: p=nan → Non Homogeneous ❌
# /opt/anaconda3/lib/python3.13/site-packages/scipy/stats/_morestats.py:3104: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom

# %%
from scipy.stats import kruskal

for col in df.select_dtypes(include='number').columns:
    grupos = [df[df['type'] == t][col] for t in df['type'].unique()]
    stat, p = kruskal(*grupos)
    resultado = "Significantly Different ✅" if p < 0.05 else "Not Significantly Different ❌"
    print(f"{col}: p={p:.4f} → {resultado}")
# Out:
# ri: p=0.0025 → Significantly Different ✅
# na: p=0.0000 → Significantly Different ✅
# mg: p=0.0000 → Significantly Different ✅
# al: p=0.0000 → Significantly Different ✅
# si: p=0.0015 → Significantly Different ✅
# k: p=0.0000 → Significantly Different ✅
# ca: p=0.0021 → Significantly Different ✅
# ba: p=0.0000 → Significantly Different ✅
# fe: p=0.0210 → Significantly Different ✅
# type: p=0.0000 → Significantly Different ✅

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix - Glass Dataset')
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
X = df.drop(columns=['type'])
y = df['type']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((170, 9), (170,), (43, 9), (43,))

# %%
error_rates = []
k_range = range(1, 31)

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    preds = knn.predict(X_test)
    error_rates.append(1 - accuracy_score(y_test, preds))

# %%
plt.figure(figsize=(10, 5))
plt.plot(k_range, error_rates, marker='o', color='steelblue')
plt.title('KNN - Error Rate por valor de K')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.xticks(k_range)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %%
print("KNN (K=3)")
print(f"Accuracy: {accuracy_score(y_test, y_pred_knn):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# KNN (K=3)
# Accuracy: 0.7674
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.83      0.71      0.77        14
#            2       0.71      1.00      0.83        15
#            3       0.50      0.33      0.40         3
#            5       1.00      0.33      0.50         3
#            6       1.00      0.50      0.67         2
#            7       0.83      0.83      0.83         6
#
#     accuracy                           0.77        43
#    macro avg       0.81      0.62      0.67        43
# weighted avg       0.79      0.77      0.75        43

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_knn), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - KNN (K=3)')
plt.ylabel('Real')
plt.xlabel('Predcted')
plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print("Random Forest")
print(f"Accuracy: {accuracy_score(y_test, y_pred_rf):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest
# Accuracy: 0.8372
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.81      0.93      0.87        14
#            2       0.85      0.73      0.79        15
#            3       1.00      0.67      0.80         3
#            5       0.67      0.67      0.67         3
#            6       0.67      1.00      0.80         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.84        43
#    macro avg       0.83      0.83      0.82        43
# weighted avg       0.85      0.84      0.84        43

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix - Random Forest')
plt.ylabel('Real')
plt.xlabel('Predcted')
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Cross Validation - KNN
knn_cv = KNeighborsClassifier(n_neighbors=3)
knn_scores = cross_val_score(knn_cv, X_scaled, y, cv=10, scoring='accuracy')

# Cross Validation - Random Forest
rf_cv = RandomForestClassifier(n_estimators=100, random_state=42)
rf_scores = cross_val_score(rf_cv, X_scaled, y, cv=10, scoring='accuracy')
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_split.py:813: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(

# %%
print("Cross Validation (10-fold)")
print(f"KNN     - Mean: {knn_scores.mean():.4f} | Std: {knn_scores.std():.4f}")
print(f"Random Forest - Mean: {rf_scores.mean():.4f} | Std: {rf_scores.std():.4f}")
# Out:
# Cross Validation (10-fold)
# KNN     - Mean: 0.6710 | Std: 0.0876
# Random Forest - Mean: 0.7370 | Std: 0.1292

# %%
plt.figure(figsize=(8, 5))
plt.boxplot([knn_scores, rf_scores], labels=['KNN (K=3)', 'Random Forest'])
plt.title('Cross Validation - KNN vs Random Forest')
plt.ylabel('Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/n9/69dc0cws2sz4qzt9yk7vc1j40000gn/T/ipykernel_21210/253042256.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([knn_scores, rf_scores], labels=['KNN (K=3)', 'Random Forest'])

# %%
# Feature Importance - Random Forest
feat_importance = pd.Series(rf.feature_importances_, index=X.columns)
feat_importance = feat_importance.sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=feat_importance.values, y=feat_importance.index, palette='Greens_r')
plt.title('Feature Importance - Random Forest')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

print(feat_importance)
# Out:
# /var/folders/n9/69dc0cws2sz4qzt9yk7vc1j40000gn/T/ipykernel_21210/206138055.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feat_importance.values, y=feat_importance.index, palette='Greens_r')
# mg    0.162449
# al    0.159993
# ri    0.136134
# ca    0.124643
# na    0.114383
# k     0.098471
# si    0.084292
# ba    0.075449
# fe    0.044185
# dtype: float64
